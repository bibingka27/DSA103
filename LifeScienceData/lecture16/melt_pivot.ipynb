# %%
import pandas as pd

# %% [markdown]
# ### Melt()

# %%
df = pd.DataFrame({
    'Measuring point': ['A', 'B', 'C', 'D'],
    'Temperature': [23.2, 25.5, 25.0, 24.1 ],
    'Humidity': [55, 51, 60, 44],
    'Type': ['DHT22', 'DHT11', 'DHT22', 'DHT20']
})
df
# Out:
#   Measuring point  Temperature  Humidity   Type
# 0               A         23.2        55  DHT22
# 1               B         25.5        51  DHT11
# 2               C         25.0        60  DHT22
# 3               D         24.1        44  DHT20

# %%
Measuring point', 'Type'melted = pd.melt(df, id_vars=[']) # Specify column names: var_name='', value_name=''
melted
# Out:
#   Measuring point   Type     variable  value
# 0               A  DHT22  Temperature   23.2
# 1               B  DHT11  Temperature   25.5
# 2               C  DHT22  Temperature   25.0
# 3               D  DHT20  Temperature   24.1
# 4               A  DHT22     Humidity   55.0
# 5               B  DHT11     Humidity   51.0
# 6               C  DHT22     Humidity   60.0
# 7               D  DHT20     Humidity   44.0

# %% [markdown]
# ### Pivot()

# %%
df2 = pd.DataFrame({
    'Measuring point': ['A', 'B', 'A', 'B', 'A', 'B'],
    'Temperature': [23.2, 25.5, 23.4, 25.0, 24.1, 26.2 ],
    'Time': ["03:08:32", "03:08:34", "03:10:54", "03:10:56", "03:12:45", "03:12:50"],
    'Type': ['DHT22', 'DHT11', 'DHT22', 'DHT11', 'DHT22','DHT11']
})
df2
# Out:
#   Measuring point  Temperature      Time   Type
# 0               A         23.2  03:08:32  DHT22
# 1               B         25.5  03:08:34  DHT11
# 2               A         23.4  03:10:54  DHT22
# 3               B         25.0  03:10:56  DHT11
# 4               A         24.1  03:12:45  DHT22
# 5               B         26.2  03:12:50  DHT11

# %%
pivoted = df2.pivot(index=['Time', 'Type'], columns="Measuring point", values="Temperature")
pivoted
# Out:
# Measuring point     A     B
# Time     Type
# 03:08:32 DHT22   23.2   NaN
# 03:08:34 DHT11    NaN  25.5
# 03:10:54 DHT22   23.4   NaN
# 03:10:56 DHT11    NaN  25.0
# 03:12:45 DHT22   24.1   NaN
# 03:12:50 DHT11    NaN  26.2

# %%
resetindex=pivoted.reset_index()
resetindex
# Out:
# Measuring point      Time   Type     A     B
# 0                03:08:32  DHT22  23.2   NaN
# 1                03:08:34  DHT11   NaN  25.5
# 2                03:10:54  DHT22  23.4   NaN
# 3                03:10:56  DHT11   NaN  25.0
# 4                03:12:45  DHT22  24.1   NaN
# 5                03:12:50  DHT11   NaN  26.2

# %% [markdown]
# ### Reversible reshaping?
#
# Try to reshape the pivoted Dataframe using melt(), v.v.
#
# Hint: reset_index() might come in handy.

# %%
resetindex = pivoted.reset_index()
resetindex
# Out:
# Measuring point      Time   Type     A     B
# 0                03:08:32  DHT22  23.2   NaN
# 1                03:08:34  DHT11   NaN  25.5
# 2                03:10:54  DHT22  23.4   NaN
# 3                03:10:56  DHT11   NaN  25.0
# 4                03:12:45  DHT22  24.1   NaN
# 5                03:12:50  DHT11   NaN  26.2

# %%
reversed = melted.reset_index(index=["Time","Type"], columns="", values="")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Startklar\Desktop\DSA103_Repo\DSA103\LifeScienceData\.venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Time'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 reversed = melted.pivot(index=["Time","Type"], columns="Measuring Point", values="Temperature")
#
# File c:\Users\Startklar\Desktop\DSA103_Repo\DSA103\LifeScienceData\.venv\Lib\site-packages\pandas\core\frame.py:9366, in DataFrame.pivot(self, columns, index, values)
#    9359 @Substitution("")
#    9360 @Appender(_shared_docs["pivot"])
#    9361 def pivot(
#    9362     self, *, columns, index=lib.no_default, values=lib.no_default
#    9363 ) -> DataFrame:
#    9364     from pandas.core.reshape.pivot import pivot
# -> 9366     return pivot(self, index=index, columns=columns, values=values)
#
# File c:\Users\Startklar\Desktop\DSA103_Repo\DSA103\LifeScienceData\.venv\Lib\site-packages\pandas\core\reshape\pivot.py:553, in pivot(data, columns, index, values)
#     549         index_list = [
#     550             data._constructor_sliced(data.index, name=data.index.name)
#     551         ]
#     552 else:
# --> 553     index_list = [data[idx] for idx in com.convert_to_list_like(index)]
#     555 data_columns = [data[col] for col in columns_listlike]
#     556 index_list.extend(data_columns)
#
# File c:\Users\Startklar\Desktop\DSA103_Repo\DSA103\LifeScienceData\.venv\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File c:\Users\Startklar\Desktop\DSA103_Repo\DSA103\LifeScienceData\.venv\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'Time'

# %%
reversed2 = pivoted.reset_index().melt(id_vars=["Time", "Type"], var_name="Measuring point", value_name="Temperature")

# %%
reversed2
# Out:
#         Time   Type Measuring point  Temperature
# 0   03:08:32  DHT22               A         23.2
# 1   03:08:34  DHT11               A          NaN
# 2   03:10:54  DHT22               A         23.4
# 3   03:10:56  DHT11               A          NaN
# 4   03:12:45  DHT22               A         24.1
# 5   03:12:50  DHT11               A          NaN
# 6   03:08:32  DHT22               B          NaN
# 7   03:08:34  DHT11               B         25.5
# 8   03:10:54  DHT22               B          NaN
# 9   03:10:56  DHT11               B         25.0
# 10  03:12:45  DHT22               B          NaN
# 11  03:12:50  DHT11               B         26.2
