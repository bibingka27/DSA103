# %% [markdown]
# ## EDA: iris dataset - part 2: visualisations

# %% [markdown]
# ### Preparations
#
# Import libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Load cleaned dataset as iris.

# %%
# Load the iris dataset
iris_clean = pd.read_csv(r"C:\Users\Startklar\Desktop\DSA103_Repo\DSA103\python-chemistry-intro\src\dsa103\lecture 7\DSA_iris_cleaned.csv")
iris_clean.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %% [markdown]
# ### Univariate analysis

# %%
# Histograms: Distribution of each numerical feature
iris_clean.hist(figsize=(10, 8), bins=15)
plt.suptitle('Feature Distributions', fontsize=16)
plt.show()

# %%
# Boxplots to check for outliers
plt.figure(figsize=(10, 6))
sns.boxplot(data=iris_clean)
plt.title('Boxplot of All Features')
plt.show()

# %% [markdown]
# ### Bivariate analysis

# %%
# Pairplot: scatter plots between all numeric variables
sns.pairplot(iris_clean, hue='species', diag_kind='kde')
plt.suptitle('Pairplot of Features by Species', y=1.02)
plt.show()

# %%
# Correlation heatmap of all features
plt.figure(figsize=(8, 6))
sns.heatmap(iris_clean.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ### Grouped analysis
#
# Gorup ny species and first calculate the mean, then visualise some grouped features as box plots

# %%
# Mean of features per species
print("\nMean feature values per species:")
print(iris_clean.groupby('species').mean())
# Out:
# Mean feature values per species:
#             sepal length (cm)  sepal width (cm)  petal length (cm)  \
# species
# setosa                  5.006             3.428              1.462
# versicolor              5.936             2.770              4.260
# virginica               6.588             2.974              5.552
#
#             petal width (cm)
# species
# setosa                 0.246
# versicolor             1.326
# virginica              2.026

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='species', y='petal length (cm)', data=iris_clean)
plt.title('Petal Length by Species')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='species', y='sepal length (cm)', data=iris_clean)
plt.title('Sepal Length by Species')
plt.show()
